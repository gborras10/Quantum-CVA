# %%
from quantum_cva.mc_benchmark.benchmark_utils import simulate_S

# %%
import numpy as np

S0, mu, sigma = 5.0, 0.02, 0.25
M, T = 4, 0.5
t = np.linspace(0.0, T, M + 1)

Z = np.random.standard_normal(size=(10_000, M))

S_by_time = simulate_S(S0, mu, sigma, t, Z)
len(S_by_time), S_by_time[0].shape
# Out:
# (4, (10000,))
